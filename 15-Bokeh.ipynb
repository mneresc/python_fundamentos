# %% [markdown]
# # Bokeh
# Geração de gráficos com bokeh interativa browser

# %%
# Importando o módulo Bokeh
import bokeh
from bokeh.io import show, output_notebook
from bokeh.plotting import figure, output_file
from bokeh.models import ColumnDataSource
from bokeh.transform import factor_cmap
from bokeh.palettes import Spectral6

# %%
# Carregando o Bokeh 
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
# Arquivo gerado pela visualização
output_file("arquivos/Bokeh-Grafico-Interativo.html")

# %%
p = figure()

# %%
p.line([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], line_width = 2)
# Out:
# GlyphRenderer(id='1037', ...)

# %%
show(p)
output_notebook()
# Out:
#   <div class="bk-root" id="22f21ac4-d9ab-4b1d-8011-0ea7697c4261" data-root-id="1003"></div>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1358">Loading BokehJS ...</span>
#     </div>
