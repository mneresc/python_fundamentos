# %% [markdown]
# # Text mine twiter

# %% [markdown]
# ### utilizando pandas e Scikit learning

# %% [markdown]
# ## Preparando stream

# %%
# !pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in /home/marcelocabral/anaconda3/lib/python3.8/site-packages (0.15.0)

# %%
# !pip install tweepy
# Out:
# Requirement already satisfied: tweepy in /home/marcelocabral/anaconda3/lib/python3.8/site-packages (3.9.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /home/marcelocabral/anaconda3/lib/python3.8/site-packages (from tweepy) (2.24.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/marcelocabral/anaconda3/lib/python3.8/site-packages (from tweepy) (1.3.0)
# Requirement already satisfied: six>=1.10.0 in /home/marcelocabral/anaconda3/lib/python3.8/site-packages (from tweepy) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/marcelocabral/anaconda3/lib/python3.8/site-packages (from requests[socks]>=2.11.1->tweepy) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/marcelocabral/anaconda3/lib/python3.8/site-packages (from requests[socks]>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /home/marcelocabral/anaconda3/lib/python3.8/site-packages (from requests[socks]>=2.11.1->tweepy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/marcelocabral/anaconda3/lib/python3.8/site-packages (from requests[socks]>=2.11.1->tweepy) (2020.6.20)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /home/marcelocabral/anaconda3/lib/python3.8/site-packages (from requests[socks]>=2.11.1->tweepy) (1.7.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/marcelocabral/anaconda3/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->tweepy) (3.1.0)

# %%
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
from datetime import datetime
import json

# %%
#Mova o arquivo .env.example na raiz para .env
#E preencha com os dados da api key do twiter
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os
key = os.getenv("TWITTER_API_KEY")
secret = os.getenv("TWITTER_SECRET_ID")
token =  os.getenv("TWITTER_ACCESS_TOKEN")
secret_token = os.getenv("TWITTER_TOKEN_SECRET")

# %%
# Criando as chaves de autenticação
auth = OAuthHandler(key, secret)

# %%
auth.set_access_token(token,secret_token)

# %%
class TwListener(StreamListener):
    def on_data(self,dados):
        tweet = json.loads(dados)
        id_str = tweet["id_str"]
        text = tweet["text"]
        created_at = tweet["created_at"]
        obj = {"created_at":created_at,"id_str":id_str,"text":text}
        tweetind = col.insert_one(obj).inserted_id
        print (obj)
        return True

# %%
tw_listener = TwListener()

# %%
stream = Stream(auth, listener = tw_listener)

# %% [markdown]
# ## Preparando DB

# %%
# Importando do PyMongo o módulo MongoClient
from pymongo import MongoClient

# %%
# Criando a conexão ao MongoDB
client = MongoClient()

# %%
# Criando o banco de dados twitterdb
#client.drop_database('twitterdb')
db = client.twitterdb

# %%
# Criando a collection "col"
col = db.tweets

# %%
# Lista de busca pra tweets
keywords = ['Eleições americanas', 'Urna eletrônica']

# %% [markdown]
# ## coletando tweets

# %%
# Iniciando o filtro e gravando os tweets no MongoDB
stream.filter(track=keywords)
# Out:
# {'created_at': 'Sun Nov 08 00:30:00 +0000 2020', 'id_str': '1325234075972595712', 'text': 'só faltou a urna eletrônica ai kkkkkkkkkk', '_id': ObjectId('5fa73c0da3f848eb84ea3c91')}
# {'created_at': 'Sun Nov 08 00:30:01 +0000 2020', 'id_str': '1325234082884759553', 'text': 'Biden eleito. Do ponto de vista democrático o resultado das eleições americanas é um alívio pro mundo todo, contant… https://t.co/R1m1US0Emi', '_id': ObjectId('5fa73c0ea3f848eb84ea3c92')}
# {'created_at': 'Sun Nov 08 00:30:02 +0000 2020', 'id_str': '1325234085028126721', 'text': 'eu quero enfiar uma alabarda medieval nos meus olhos após ver um story de uma familiar chamando "ana paula vôlei" d… https://t.co/BSk0Sm4r01', '_id': ObjectId('5fa73c0fa3f848eb84ea3c93')}
# {'created_at': 'Sun Nov 08 00:30:02 +0000 2020', 'id_str': '1325234087402070016', 'text': 'RT @oswaldojor: A Fox News acaba de anunciar a vitória de Biden nas eleições americanas. A fraude nas urnas foi abafada pelo mecanismo. Ont…', '_id': ObjectId('5fa73c0fa3f848eb84ea3c94')}
# {'created_at': 'Sun Nov 08 00:30:02 +0000 2020', 'id_str': '1325234087439765506', 'text': 'RT @colunapatriota: URGENTE: As eleições americanas serão definidas pela SUPREMA CORTE AMERICANA, Joe Biden foi orientado a se declarar Pre…', '_id': ObjectId('5fa73c0fa3f848eb84ea3c95')}
# {'created_at': 'Sun Nov 08 00:30:03 +0000 2020', 'id_str': '1325234091080495109', 'text': 'Mídia nojenta', '_id': ObjectId('5fa73c10a3f848eb84ea3c96')}
# {'created_at': 'Sun Nov 08 00:30:10 +0000 2020', 'id_str': '1325234119845023746', 'text': 'RT @fabifbbr: Trump a partir de segunda-feira vai detonar as irregularidades das eleições americanas. #MAGA', '_id': ObjectId('5fa73c17a3f848eb84ea3c97')}
# {'created_at': 'Sun Nov 08 00:30:11 +0000 2020', 'id_str': '1325234124936896512', 'text': 'RT @Biakicis: Vamos aguardar a justiça decidir se houve ou não fraude nas eleições americanas e quem é o vencedor. Até lá, toda manifestaçã…', '_id': ObjectId('5fa73c18a3f848eb84ea3c98')}
# {'created_at': 'Sun Nov 08 00:30:12 +0000 2020', 'id_str': '1325234127008882693', 'text': 'RT @WiLLBarbudo: Os msm q estão apoiando o roubo nas eleições Americanas, ficaram quietos e apoiando Lula e Dilma enquanto roubavam o BR. T…', '_id': ObjectId('5fa73c19a3f848eb84ea3c99')}
# {'created_at': 'Sun Nov 08 00:30:15 +0000 2020', 'id_str': '1325234142548791297', 'text': 'RT @allanldsantos: Dominion é a empresa das máquinas de scam dos swing states que MUDARAM os votos de Trump para Biden.\n\nDominion Voting Sy…', '_id': ObjectId('5fa73c1da3f848eb84ea3c9a')}
# {'created_at': 'Sun Nov 08 00:30:16 +0000 2020', 'id_str': '1325234146818613250', 'text': 'RT @ToniettoChris: Sei que as eleições presidenciais norte-americanas não estão definidas, graças a Deus! Contudo, não deixa de ser um dia…', '_id': ObjectId('5fa73c1ea3f848eb84ea3c9b')}
# {'created_at': 'Sun Nov 08 00:30:17 +0000 2020', 'id_str': '1325234150366916608', 'text': 'RT @Biakicis: Vamos aguardar a justiça decidir se houve ou não fraude nas eleições americanas e quem é o vencedor. Até lá, toda manifestaçã…', '_id': ObjectId('5fa73c1ea3f848eb84ea3c9c')}
# {'created_at': 'Sun Nov 08 00:30:18 +0000 2020', 'id_str': '1325234154372558849', 'text': 'RT @iaradsobral: Vi muitos jovens a acompanhar as eleições americanas de perto e a sentir o medo de uma reeleição. Espero que transfiram es…', '_id': ObjectId('5fa73c1fa3f848eb84ea3c9d')}
# {'created_at': 'Sun Nov 08 00:30:20 +0000 2020', 'id_str': '1325234162786324481', 'text': 'RT @iaradsobral: Vi muitos jovens a acompanhar as eleições americanas de perto e a sentir o medo de uma reeleição. Espero que transfiram es…', '_id': ObjectId('5fa73c21a3f848eb84ea3c9e')}
# {'created_at': 'Sun Nov 08 00:30:23 +0000 2020', 'id_str': '1325234174027046914', 'text': 'RT @FariaLimaElevat: Como bom brasileiro que você é, já repassou todos o memes das eleições americanas, já viu todos os videos de vereadore…', '_id': ObjectId('5fa73c24a3f848eb84ea3c9f')}
# {'created_at': 'Sun Nov 08 00:30:24 +0000 2020', 'id_str': '1325234180041609223', 'text': 'RT @disturst: És fã das eleições americanas? Diz 3 álbuns', '_id': ObjectId('5fa73c26a3f848eb84ea3ca0')}
# {'created_at': 'Sun Nov 08 00:30:32 +0000 2020', 'id_str': '1325234211436032000', 'text': 'RT @oswaldojor: A Fox News acaba de anunciar a vitória de Biden nas eleições americanas. A fraude nas urnas foi abafada pelo mecanismo. Ont…', '_id': ObjectId('5fa73c2da3f848eb84ea3ca1')}
# {'created_at': 'Sun Nov 08 00:30:32 +0000 2020', 'id_str': '1325234211633164288', 'text': 'RT @GugaNoblat: Se nenhum filho do Bolsonaro falou merda sobre as eleições americanas hoje, é sinal que foram orientados a se calar. Que bo…', '_id': ObjectId('5fa73c2da3f848eb84ea3ca2')}
# {'created_at': 'Sun Nov 08 00:30:37 +0000 2020', 'id_str': '1325234234227888130', 'text': 'RT @GugaNoblat: Se nenhum filho do Bolsonaro falou merda sobre as eleições americanas hoje, é sinal que foram orientados a se calar. Que bo…', '_id': ObjectId('5fa73c32a3f848eb84ea3ca3')}
# {'created_at': 'Sun Nov 08 00:30:40 +0000 2020', 'id_str': '1325234247272181760', 'text': 'Pro governo Bolsonaro o melhor a se fazer é ter paciência e se manter em silêncio até o fim das eleições. \n Não par… https://t.co/5Y8O7Sm3X7', '_id': ObjectId('5fa73c36a3f848eb84ea3ca4')}
# {'created_at': 'Sun Nov 08 00:30:43 +0000 2020', 'id_str': '1325234257678266368', 'text': "RT @AleGZahra38: ' A gente virou ' , diz a torcedora do Falecido !\n\nA Guerra está declarada !\nA Imprensa Corrompida é um dos maiores inimig…", '_id': ObjectId('5fa73c38a3f848eb84ea3ca5')}
# {'created_at': 'Sun Nov 08 00:30:44 +0000 2020', 'id_str': '1325234261977395200', 'text': 'RT @GugaNoblat: Se nenhum filho do Bolsonaro falou merda sobre as eleições americanas hoje, é sinal que foram orientados a se calar. Que bo…', '_id': ObjectId('5fa73c39a3f848eb84ea3ca6')}
# {'created_at': 'Sun Nov 08 00:30:45 +0000 2020', 'id_str': '1325234264938606592', 'text': '@MaluMor60923600  esse é o próximo #Presidente', '_id': ObjectId('5fa73c3aa3f848eb84ea3ca7')}
# {'created_at': 'Sun Nov 08 00:30:46 +0000 2020', 'id_str': '1325234272127635456', 'text': 'RT @GugaNoblat: Se nenhum filho do Bolsonaro falou merda sobre as eleições americanas hoje, é sinal que foram orientados a se calar. Que bo…', '_id': ObjectId('5fa73c3ba3f848eb84ea3ca8')}
# {'created_at': 'Sun Nov 08 00:30:46 +0000 2020', 'id_str': '1325234272505098242', 'text': 'RT @colunapatriota: URGENTE: As eleições americanas serão definidas pela SUPREMA CORTE AMERICANA, Joe Biden foi orientado a se declarar Pre…', '_id': ObjectId('5fa73c3ca3f848eb84ea3ca9')}
# {'created_at': 'Sun Nov 08 00:30:51 +0000 2020', 'id_str': '1325234289856835585', 'text': 'RT @GugaNoblat: Se nenhum filho do Bolsonaro falou merda sobre as eleições americanas hoje, é sinal que foram orientados a se calar. Que bo…', '_id': ObjectId('5fa73c40a3f848eb84ea3caa')}
# {'created_at': 'Sun Nov 08 00:30:52 +0000 2020', 'id_str': '1325234295221465088', 'text': 'RT @GugaNoblat: Se nenhum filho do Bolsonaro falou merda sobre as eleições americanas hoje, é sinal que foram orientados a se calar. Que bo…', '_id': ObjectId('5fa73c41a3f848eb84ea3cab')}
# {'created_at': 'Sun Nov 08 00:30:56 +0000 2020', 'id_str': '1325234311818334208', 'text': 'RT @LorenzonItalo: Rapaz, eu sempre achei que se Trump vencesse as eleições americanas seria apenas no colégio eleitoral e que Biden vencer…', '_id': ObjectId('5fa73c45a3f848eb84ea3cac')}
# {'created_at': 'Sun Nov 08 00:31:00 +0000 2020', 'id_str': '1325234331560923138', 'text': 'Presidente @jairbolsonaro atende ao chamado do Donald Trump, a fraude das eleições americanas se deu por um ataque… https://t.co/X7wRytJjs7', '_id': ObjectId('5fa73c4aa3f848eb84ea3cad')}
# {'created_at': 'Sun Nov 08 00:31:01 +0000 2020', 'id_str': '1325234335260274691', 'text': 'RT @iaradsobral: Vi muitos jovens a acompanhar as eleições americanas de perto e a sentir o medo de uma reeleição. Espero que transfiram es…', '_id': ObjectId('5fa73c4aa3f848eb84ea3cae')}
# {'created_at': 'Sun Nov 08 00:31:02 +0000 2020', 'id_str': '1325234337089019909', 'text': 'Não me importo c/ o resultado de eleições americanas. Mas ver derrotado um sujeito mentiroso, arrogante, símbolo de… https://t.co/R2BHQcN75s', '_id': ObjectId('5fa73c4ba3f848eb84ea3caf')}
# {'created_at': 'Sun Nov 08 00:31:03 +0000 2020', 'id_str': '1325234343317483520', 'text': 'RT @GugaNoblat: Se nenhum filho do Bolsonaro falou merda sobre as eleições americanas hoje, é sinal que foram orientados a se calar. Que bo…', '_id': ObjectId('5fa73c4ca3f848eb84ea3cb0')}
# {'created_at': 'Sun Nov 08 00:31:09 +0000 2020', 'id_str': '1325234369246715904', 'text': 'RT @conservadoratha: Eu tinha uma vida tranquila até conhecer o Bolsonaro. Agora, até as eleições americanas me deixam apreensiva.🤣🤣🤣🤣', '_id': ObjectId('5fa73c53a3f848eb84ea3cb1')}
# {'created_at': 'Sun Nov 08 00:31:11 +0000 2020', 'id_str': '1325234376196698113', 'text': 'RT @colunapatriota: URGENTE: As eleições americanas serão definidas pela SUPREMA CORTE AMERICANA, Joe Biden foi orientado a se declarar Pre…', '_id': ObjectId('5fa73c54a3f848eb84ea3cb2')}
# {'created_at': 'Sun Nov 08 00:31:15 +0000 2020', 'id_str': '1325234390444740610', 'text': 'Não paro de rir dos Bolsominions criando uma teoria da conspiração e dizendo que houve uma fraude enorme nas eleiçõ… https://t.co/GP3Adv3ZVD', '_id': ObjectId('5fa73c58a3f848eb84ea3cb3')}
# {'created_at': 'Sun Nov 08 00:31:16 +0000 2020', 'id_str': '1325234397067571200', 'text': 'RT @oswaldojor: A Fox News acaba de anunciar a vitória de Biden nas eleições americanas. A fraude nas urnas foi abafada pelo mecanismo. Ont…', '_id': ObjectId('5fa73c59a3f848eb84ea3cb4')}
# {'created_at': 'Sun Nov 08 00:31:17 +0000 2020', 'id_str': '1325234400724987904', 'text': 'RT @Biakicis: Vamos aguardar a justiça decidir se houve ou não fraude nas eleições americanas e quem é o vencedor. Até lá, toda manifestaçã…', '_id': ObjectId('5fa73c5aa3f848eb84ea3cb5')}
# {'created_at': 'Sun Nov 08 00:31:18 +0000 2020', 'id_str': '1325234406961897472', 'text': 'Parece que as eleições do Vasco da Gama é mais complicada que as eleições americanas...', '_id': ObjectId('5fa73c5ca3f848eb84ea3cb6')}
# {'created_at': 'Sun Nov 08 00:31:19 +0000 2020', 'id_str': '1325234410619277312', 'text': 'KKKKKKKKKK é foda', '_id': ObjectId('5fa73c5ca3f848eb84ea3cb7')}
# {'created_at': 'Sun Nov 08 00:31:20 +0000 2020', 'id_str': '1325234413190471680', 'text': 'RT @allanldsantos: Dominion é a empresa das máquinas de scam dos swing states que MUDARAM os votos de Trump para Biden.\n\nDominion Voting Sy…', '_id': ObjectId('5fa73c5da3f848eb84ea3cb8')}
# {'created_at': 'Sun Nov 08 00:31:21 +0000 2020', 'id_str': '1325234417976152064', 'text': 'RT @Biakicis: Vamos aguardar a justiça decidir se houve ou não fraude nas eleições americanas e quem é o vencedor. Até lá, toda manifestaçã…', '_id': ObjectId('5fa73c5ea3f848eb84ea3cb9')}
# {'created_at': 'Sun Nov 08 00:31:21 +0000 2020', 'id_str': '1325234418634645504', 'text': 'RT @Madruga004: Caraca olha a torcida da Globo Lixo, para noticiar algo sobre eleições americanas.\n\n"A Gente Virou".\n\nCalma, ainda vai ter…', '_id': ObjectId('5fa73c5ea3f848eb84ea3cba')}
# {'created_at': 'Sun Nov 08 00:31:24 +0000 2020', 'id_str': '1325234428570963968', 'text': 'boatos que o resultado das eleições americanas so saiu hoje porque a beyonce tem aquela musica 7/11\n\nela preveu ess… https://t.co/jo4dCMcdO1', '_id': ObjectId('5fa73c62a3f848eb84ea3cbb')}
# {'created_at': 'Sun Nov 08 00:31:26 +0000 2020', 'id_str': '1325234437253115914', 'text': 'RT @SaBolsonaro: Para fraudar as eleições americanas, eles tiveram de providenciar uma Pandemia, que por sua vez serviu de justificativa pa…', '_id': ObjectId('5fa73c63a3f848eb84ea3cbc')}
# {'created_at': 'Sun Nov 08 00:31:26 +0000 2020', 'id_str': '1325234437609705473', 'text': 'RT @Biakicis: Vamos aguardar a justiça decidir se houve ou não fraude nas eleições americanas e quem é o vencedor. Até lá, toda manifestaçã…', '_id': ObjectId('5fa73c63a3f848eb84ea3cbd')}
# {'created_at': 'Sun Nov 08 00:31:26 +0000 2020', 'id_str': '1325234439236972544', 'text': 'RT @bernardokuster2: A mídia hoje correu anunciar a vitória decisiva de Joe Biden nas eleições americanas. Imagine, só imagine!, se depois…', '_id': ObjectId('5fa73c63a3f848eb84ea3cbe')}
# {'created_at': 'Sun Nov 08 00:31:33 +0000 2020', 'id_str': '1325234468987269120', 'text': 'A única coisa que eu não consigo entender é a situação no AMAPÁ não ter essa repercussão toda que as eleições americanas estão tendo...', '_id': ObjectId('5fa73c6aa3f848eb84ea3cbf')}
# {'created_at': 'Sun Nov 08 00:31:38 +0000 2020', 'id_str': '1325234489946222592', 'text': 'RT @Biakicis: Vamos aguardar a justiça decidir se houve ou não fraude nas eleições americanas e quem é o vencedor. Até lá, toda manifestaçã…', '_id': ObjectId('5fa73c6fa3f848eb84ea3cc0')}
# {'created_at': 'Sun Nov 08 00:31:39 +0000 2020', 'id_str': '1325234491409960960', 'text': 'RT @JornalBSM: Suprema Corte decide contar em separado os votos tardios da Pensilvânia\n\nA cada hora que passa, torna-se mais evidente que o…', '_id': ObjectId('5fa73c70a3f848eb84ea3cc1')}
# {'created_at': 'Sun Nov 08 00:31:39 +0000 2020', 'id_str': '1325234494174060544', 'text': 'RT @JornalBSM: Mídia “elege” Biden; Trump vai à Justiça\n\nMesmo com denúncias de fraudes, imprensa anuncia o democrata Joe Biden como venced…', '_id': ObjectId('5fa73c70a3f848eb84ea3cc2')}
# {'created_at': 'Sun Nov 08 00:31:42 +0000 2020', 'id_str': '1325234503728631808', 'text': 'RT @iaradsobral: Vi muitos jovens a acompanhar as eleições americanas de perto e a sentir o medo de uma reeleição. Espero que transfiram es…', '_id': ObjectId('5fa73c73a3f848eb84ea3cc3')}
# {'created_at': 'Sun Nov 08 00:31:45 +0000 2020', 'id_str': '1325234518278754306', 'text': 'Essa aq é a realidade no Amapá enquanto o resto do Brasil discute sobre as eleições americanas, ñ consigo entender,… https://t.co/hrGBxlWQuq', '_id': ObjectId('5fa73c76a3f848eb84ea3cc4')}
# {'created_at': 'Sun Nov 08 00:31:46 +0000 2020', 'id_str': '1325234522510782466', 'text': 'Bolsonaro agiu como líder de torcida de Trump durante as eleições americanas. Sinal de pouca inteligência. Agora é… https://t.co/d9k4bprUdF', '_id': ObjectId('5fa73c77a3f848eb84ea3cc5')}
# {'created_at': 'Sun Nov 08 00:31:46 +0000 2020', 'id_str': '1325234523618111488', 'text': 'RT @FariaLimaElevat: Como bom brasileiro que você é, já repassou todos o memes das eleições americanas, já viu todos os videos de vereadore…', '_id': ObjectId('5fa73c77a3f848eb84ea3cc6')}
# {'created_at': 'Sun Nov 08 00:31:50 +0000 2020', 'id_str': '1325234538403033089', 'text': 'RT @CarlosPanitz: Se tem algo que as eleições americanas estão servindo é para mostrar que a maquina globalista já tinha um plano B para as…', '_id': ObjectId('5fa73c7ba3f848eb84ea3cc7')}
# {'created_at': 'Sun Nov 08 00:31:50 +0000 2020', 'id_str': '1325234539518701568', 'text': 'RT @oswaldojor: A Fox News acaba de anunciar a vitória de Biden nas eleições americanas. A fraude nas urnas foi abafada pelo mecanismo. Ont…', '_id': ObjectId('5fa73c7ba3f848eb84ea3cc8')}
# {'created_at': 'Sun Nov 08 00:31:50 +0000 2020', 'id_str': '1325234540906999808', 'text': 'SUPREMA CORTE É  CONSERVADORA NA MAIORIA.', '_id': ObjectId('5fa73c7ca3f848eb84ea3cc9')}
# {'created_at': 'Sun Nov 08 00:31:53 +0000 2020', 'id_str': '1325234552177119234', 'text': 'RT @Leomira12: #GoTrump2020 \n@realDonaldTrump\nPresidente🇺🇸❤️', '_id': ObjectId('5fa73c7ea3f848eb84ea3cca')}
# {'created_at': 'Sun Nov 08 00:31:53 +0000 2020', 'id_str': '1325234552336429056', 'text': 'RT @Biakicis: Vamos aguardar a justiça decidir se houve ou não fraude nas eleições americanas e quem é o vencedor. Até lá, toda manifestaçã…', '_id': ObjectId('5fa73c7ea3f848eb84ea3ccb')}
# {'created_at': 'Sun Nov 08 00:32:04 +0000 2020', 'id_str': '1325234598993911808', 'text': 'RT @conservadoratha: Eu tinha uma vida tranquila até conhecer o Bolsonaro. Agora, até as eleições americanas me deixam apreensiva.🤣🤣🤣🤣', '_id': ObjectId('5fa73c89a3f848eb84ea3ccc')}
# {'created_at': 'Sun Nov 08 00:32:05 +0000 2020', 'id_str': '1325234601078435842', 'text': 'RT @alebarbieriadv: Estamos a 8 dias das eleições municipais, mas o único assunto que engaja o público são as eleições nos EUA. Se o brasil…', '_id': ObjectId('5fa73c8aa3f848eb84ea3ccd')}
# {'created_at': 'Sun Nov 08 00:32:08 +0000 2020', 'id_str': '1325234616345776130', 'text': '@realDonaldTrump O Virus chinês teve o propósito da fraude nas eleições americanas através da votação por correio!!!', '_id': ObjectId('5fa73c8ea3f848eb84ea3cce')}
# {'created_at': 'Sun Nov 08 00:32:08 +0000 2020', 'id_str': '1325234616421273600', 'text': 'RT @lordivan22: Foram 10 dias intensos de cobertura das eleições americanas. Agradeço a todos pela paciência e audiência mas acima de tudo…', '_id': ObjectId('5fa73c8ea3f848eb84ea3ccf')}
# {'created_at': 'Sun Nov 08 00:32:09 +0000 2020', 'id_str': '1325234620309397504', 'text': 'RT @iaradsobral: Vi muitos jovens a acompanhar as eleições americanas de perto e a sentir o medo de uma reeleição. Espero que transfiram es…', '_id': ObjectId('5fa73c8ea3f848eb84ea3cd0')}
# {'created_at': 'Sun Nov 08 00:32:10 +0000 2020', 'id_str': '1325234622351937542', 'text': 'RT @Biakicis: Vamos aguardar a justiça decidir se houve ou não fraude nas eleições americanas e quem é o vencedor. Até lá, toda manifestaçã…', '_id': ObjectId('5fa73c8fa3f848eb84ea3cd1')}
# {'created_at': 'Sun Nov 08 00:32:10 +0000 2020', 'id_str': '1325234624679841792', 'text': 'RT @oswaldojor: A Fox News acaba de anunciar a vitória de Biden nas eleições americanas. A fraude nas urnas foi abafada pelo mecanismo. Ont…', '_id': ObjectId('5fa73c90a3f848eb84ea3cd2')}
# {'created_at': 'Sun Nov 08 00:32:18 +0000 2020', 'id_str': '1325234655696711681', 'text': 'Enquanto isto, cá no Tugão o que importa é o Biden, o Trump e as eleições norte americanas 🤦🏻\u200d♂️', '_id': ObjectId('5fa73c97a3f848eb84ea3cd3')}
# {'created_at': 'Sun Nov 08 00:32:20 +0000 2020', 'id_str': '1325234663804301312', 'text': 'RT @Madruga004: Caraca olha a torcida da Globo Lixo, para noticiar algo sobre eleições americanas.\n\n"A Gente Virou".\n\nCalma, ainda vai ter…', '_id': ObjectId('5fa73c99a3f848eb84ea3cd4')}
# {'created_at': 'Sun Nov 08 00:32:21 +0000 2020', 'id_str': '1325234669063901187', 'text': 'RT @bernardokuster2: A mídia hoje correu anunciar a vitória decisiva de Joe Biden nas eleições americanas. Imagine, só imagine!, se depois…', '_id': ObjectId('5fa73c9aa3f848eb84ea3cd5')}
# {'created_at': 'Sun Nov 08 00:32:30 +0000 2020', 'id_str': '1325234706108067842', 'text': 'RT @colunapatriota: URGENTE: As eleições americanas serão definidas pela SUPREMA CORTE AMERICANA, Joe Biden foi orientado a se declarar Pre…', '_id': ObjectId('5fa73ca3a3f848eb84ea3cd6')}
# {'created_at': 'Sun Nov 08 00:32:32 +0000 2020', 'id_str': '1325234713435496450', 'text': 'Leia 42 denúncias de fraude das eleições americanas https://t.co/vJxDmwQuGX via @estudosn', '_id': ObjectId('5fa73ca5a3f848eb84ea3cd7')}
# {'created_at': 'Sun Nov 08 00:32:32 +0000 2020', 'id_str': '1325234713687171074', 'text': 'RT @oswaldojor: A Fox News acaba de anunciar a vitória de Biden nas eleições americanas. A fraude nas urnas foi abafada pelo mecanismo. Ont…', '_id': ObjectId('5fa73ca5a3f848eb84ea3cd8')}
# {'created_at': 'Sun Nov 08 00:32:32 +0000 2020', 'id_str': '1325234716614778884', 'text': 'RT @GugaNoblat: Se nenhum filho do Bolsonaro falou merda sobre as eleições americanas hoje, é sinal que foram orientados a se calar. Que bo…', '_id': ObjectId('5fa73ca5a3f848eb84ea3cd9')}
# {'created_at': 'Sun Nov 08 00:32:33 +0000 2020', 'id_str': '1325234718732857351', 'text': 'RT @colunapatriota: URGENTE: As eleições americanas serão definidas pela SUPREMA CORTE AMERICANA, Joe Biden foi orientado a se declarar Pre…', '_id': ObjectId('5fa73ca6a3f848eb84ea3cda')}
# {'created_at': 'Sun Nov 08 00:32:41 +0000 2020', 'id_str': '1325234754057285633', 'text': 'Escutei hj de uma pessoa empolgada com o resultado das eleições americanas "Biden é mt comunista". Queria deixar isso aqui pra vcs', '_id': ObjectId('5fa73caea3f848eb84ea3cdb')}
# {'created_at': 'Sun Nov 08 00:32:43 +0000 2020', 'id_str': '1325234762278166534', 'text': 'RT @WiLLBarbudo: Os msm q estão apoiando o roubo nas eleições Americanas, ficaram quietos e apoiando Lula e Dilma enquanto roubavam o BR. T…', '_id': ObjectId('5fa73cb0a3f848eb84ea3cdc')}
# {'created_at': 'Sun Nov 08 00:32:45 +0000 2020', 'id_str': '1325234769987313670', 'text': 'RT @oswaldojor: A Fox News acaba de anunciar a vitória de Biden nas eleições americanas. A fraude nas urnas foi abafada pelo mecanismo. Ont…', '_id': ObjectId('5fa73cb2a3f848eb84ea3cdd')}
# {'created_at': 'Sun Nov 08 00:32:45 +0000 2020', 'id_str': '1325234771971149826', 'text': '🚨🚨 FIQUEMOS de olho em 2022. 👀\n\nSe há lição nessa vergonhosa eleição dos EUA, é que aqui será bem mais descarado, c… https://t.co/QLH4VgTV4x', '_id': ObjectId('5fa73cb3a3f848eb84ea3cde')}
# {'created_at': 'Sun Nov 08 00:32:47 +0000 2020', 'id_str': '1325234776563920896', 'text': 'Sobre as eleições americanas: melhor para o mundo, melhor para a sanidade a saída do laranjão. Porém, longe do que… https://t.co/U36ZiURrHa', '_id': ObjectId('5fa73cb4a3f848eb84ea3cdf')}
# {'created_at': 'Sun Nov 08 00:32:49 +0000 2020', 'id_str': '1325234786965852161', 'text': 'RT @bernardokuster2: A mídia hoje correu anunciar a vitória decisiva de Joe Biden nas eleições americanas. Imagine, só imagine!, se depois…', '_id': ObjectId('5fa73cb6a3f848eb84ea3ce0')}
# {'created_at': 'Sun Nov 08 00:32:52 +0000 2020', 'id_str': '1325234799372603402', 'text': 'RT @xfischer: O idiota foi passear onde tudo está calmo, para verificar se está calmo. Vai para a Pensilvânia, ver se entra numa área de ap…', '_id': ObjectId('5fa73cb9a3f848eb84ea3ce1')}
# {'created_at': 'Sun Nov 08 00:32:52 +0000 2020', 'id_str': '1325234800333033472', 'text': 'É nesse modelo kkkkkk', '_id': ObjectId('5fa73cb9a3f848eb84ea3ce2')}
# {'created_at': 'Sun Nov 08 00:32:58 +0000 2020', 'id_str': '1325234825847074817', 'text': 'RT @conservadoratha: Eu tinha uma vida tranquila até conhecer o Bolsonaro. Agora, até as eleições americanas me deixam apreensiva.🤣🤣🤣🤣', '_id': ObjectId('5fa73cbfa3f848eb84ea3ce3')}
# {'created_at': 'Sun Nov 08 00:33:02 +0000 2020', 'id_str': '1325234842150297605', 'text': 'RT @Biakicis: Vamos aguardar a justiça decidir se houve ou não fraude nas eleições americanas e quem é o vencedor. Até lá, toda manifestaçã…', '_id': ObjectId('5fa73cc3a3f848eb84ea3ce4')}
# {'created_at': 'Sun Nov 08 00:33:04 +0000 2020', 'id_str': '1325234847615504391', 'text': 'Olhem que interessante essa informação trazida pelo conservador Ricardo.\nEleições Americanas em 2000 - Bush e Al Go… https://t.co/PUpgyk0BSX', '_id': ObjectId('5fa73cc5a3f848eb84ea3ce5')}
# {'created_at': 'Sun Nov 08 00:33:06 +0000 2020', 'id_str': '1325234856230612995', 'text': 'RT @disturst: És fã das eleições americanas? Diz 3 álbuns', '_id': ObjectId('5fa73cc7a3f848eb84ea3ce6')}
# {'created_at': 'Sun Nov 08 00:33:10 +0000 2020', 'id_str': '1325234873553063936', 'text': '@Saraluxoo @_gabrielvf @Augusto09847768 @conservadoratha @gugachacra É um cabo eleitoral do Biden. Morador de Taboã… https://t.co/juXNik4Qvu', '_id': ObjectId('5fa73ccba3f848eb84ea3ce7')}
# {'created_at': 'Sun Nov 08 00:33:11 +0000 2020', 'id_str': '1325234877621547009', 'text': 'Resumo da batalha Biden X Trump nas eleições americanas https://t.co/9FT9bmeeBb', '_id': ObjectId('5fa73ccca3f848eb84ea3ce8')}
# {'created_at': 'Sun Nov 08 00:33:14 +0000 2020', 'id_str': '1325234893513764865', 'text': 'RT @perolastewart: cadê a mídia falando do que está acontecendo no Amapá? Plantão, notícias.... cadê? Se fosse em São Paulo, Rio, Brasília…', '_id': ObjectId('5fa73cd0a3f848eb84ea3ce9')}
# {'created_at': 'Sun Nov 08 00:33:15 +0000 2020', 'id_str': '1325234893798957059', 'text': '@beatrizbulla @Estadao Dentre outros fatos, as eleições norte-americanas mostraram a importância e o valor do siste… https://t.co/0GsVYUhazu', '_id': ObjectId('5fa73cd0a3f848eb84ea3cea')}
# {'created_at': 'Sun Nov 08 00:33:16 +0000 2020', 'id_str': '1325234899385802752', 'text': 'RT @WiLLBarbudo: Os msm q estão apoiando o roubo nas eleições Americanas, ficaram quietos e apoiando Lula e Dilma enquanto roubavam o BR. T…', '_id': ObjectId('5fa73cd1a3f848eb84ea3ceb')}
# {'created_at': 'Sun Nov 08 00:33:19 +0000 2020', 'id_str': '1325234913428336642', 'text': 'RT @GugaNoblat: Se nenhum filho do Bolsonaro falou merda sobre as eleições americanas hoje, é sinal que foram orientados a se calar. Que bo…', '_id': ObjectId('5fa73cd4a3f848eb84ea3cec')}
# {'created_at': 'Sun Nov 08 00:33:19 +0000 2020', 'id_str': '1325234913671589892', 'text': 'RT @GugaNoblat: Se nenhum filho do Bolsonaro falou merda sobre as eleições americanas hoje, é sinal que foram orientados a se calar. Que bo…', '_id': ObjectId('5fa73cd4a3f848eb84ea3ced')}
# {'created_at': 'Sun Nov 08 00:33:21 +0000 2020', 'id_str': '1325234919849734147', 'text': 'RT @ToniettoChris: Sei que as eleições presidenciais norte-americanas não estão definidas, graças a Deus! Contudo, não deixa de ser um dia…', '_id': ObjectId('5fa73cd6a3f848eb84ea3cee')}
# {'created_at': 'Sun Nov 08 00:33:22 +0000 2020', 'id_str': '1325234926145376261', 'text': 'RT @colunapatriota: URGENTE: As eleições americanas serão definidas pela SUPREMA CORTE AMERICANA, Joe Biden foi orientado a se declarar Pre…', '_id': ObjectId('5fa73cd7a3f848eb84ea3cef')}
# {'created_at': 'Sun Nov 08 00:33:26 +0000 2020', 'id_str': '1325234942922645504', 'text': 'É verdade. Vamos aguardar os próximos capítulos', '_id': ObjectId('5fa73cdba3f848eb84ea3cf0')}
# {'created_at': 'Sun Nov 08 00:33:27 +0000 2020', 'id_str': '1325234946236100608', 'text': 'RT @conservadoratha: Eu tinha uma vida tranquila até conhecer o Bolsonaro. Agora, até as eleições americanas me deixam apreensiva.🤣🤣🤣🤣', '_id': ObjectId('5fa73cdca3f848eb84ea3cf1')}
# {'created_at': 'Sun Nov 08 00:33:29 +0000 2020', 'id_str': '1325234955472023554', 'text': 'RT @GugaNoblat: Se nenhum filho do Bolsonaro falou merda sobre as eleições americanas hoje, é sinal que foram orientados a se calar. Que bo…', '_id': ObjectId('5fa73cdea3f848eb84ea3cf2')}
# {'created_at': 'Sun Nov 08 00:33:33 +0000 2020', 'id_str': '1325234970403753989', 'text': 'RT @JornalBSM: Suprema Corte decide contar em separado os votos tardios da Pensilvânia\n\nA cada hora que passa, torna-se mais evidente que o…', '_id': ObjectId('5fa73ce2a3f848eb84ea3cf3')}
# {'created_at': 'Sun Nov 08 00:33:33 +0000 2020', 'id_str': '1325234972840644608', 'text': 'RT @conservadoratha: Eu tinha uma vida tranquila até conhecer o Bolsonaro. Agora, até as eleições americanas me deixam apreensiva.🤣🤣🤣🤣', '_id': ObjectId('5fa73ce3a3f848eb84ea3cf4')}
# {'created_at': 'Sun Nov 08 00:33:33 +0000 2020', 'id_str': '1325234972572217345', 'text': 'https://t.co/sO1YADuQFP', '_id': ObjectId('5fa73ce3a3f848eb84ea3cf5')}
# {'created_at': 'Sun Nov 08 00:33:37 +0000 2020', 'id_str': '1325234986761547779', 'text': 'RT @colunapatriota: URGENTE: As eleições americanas serão definidas pela SUPREMA CORTE AMERICANA, Joe Biden foi orientado a se declarar Pre…', '_id': ObjectId('5fa73ce6a3f848eb84ea3cf6')}
# {'created_at': 'Sun Nov 08 00:33:37 +0000 2020', 'id_str': '1325234989823356929', 'text': 'RT @ToniettoChris: Sei que as eleições presidenciais norte-americanas não estão definidas, graças a Deus! Contudo, não deixa de ser um dia…', '_id': ObjectId('5fa73ce7a3f848eb84ea3cf7')}
# {'created_at': 'Sun Nov 08 00:33:41 +0000 2020', 'id_str': '1325235006680260608', 'text': '"It\'s easy to do it the cheap way, and get away with stuff, but it comes back around". A coisa mais linda q vc vai… https://t.co/jZqoZ0olnI', '_id': ObjectId('5fa73ceba3f848eb84ea3cf8')}
# {'created_at': 'Sun Nov 08 00:33:42 +0000 2020', 'id_str': '1325235008756457472', 'text': 'RT @iaradsobral: Vi muitos jovens a acompanhar as eleições americanas de perto e a sentir o medo de uma reeleição. Espero que transfiram es…', '_id': ObjectId('5fa73ceba3f848eb84ea3cf9')}
# {'created_at': 'Sun Nov 08 00:33:44 +0000 2020', 'id_str': '1325235017023430657', 'text': 'RT @Biakicis: Vamos aguardar a justiça decidir se houve ou não fraude nas eleições americanas e quem é o vencedor. Até lá, toda manifestaçã…', '_id': ObjectId('5fa73ceda3f848eb84ea3cfa')}
# {'created_at': 'Sun Nov 08 00:33:52 +0000 2020', 'id_str': '1325235052352073731', 'text': 'RT @rmotta2: Para quem está inclinado a comprar a versão da mídia para as eleições americanas, recomendo lembrar de alguns meses atrás quan…', '_id': ObjectId('5fa73cf5a3f848eb84ea3cfb')}
# {'created_at': 'Sun Nov 08 00:33:53 +0000 2020', 'id_str': '1325235053241176070', 'text': 'Divas do pop comemoram vitória de Biden nas eleições americanas https://t.co/4kJlIZvmnh', '_id': ObjectId('5fa73cf6a3f848eb84ea3cfc')}
# {'created_at': 'Sun Nov 08 00:33:53 +0000 2020', 'id_str': '1325235053547433984', 'text': 'Sentindo a leveza das eleições americanas chega o questionamento ... O que você fará quando esse momento chegar nas eleições brasileiras?', '_id': ObjectId('5fa73cf6a3f848eb84ea3cfd')}
# {'created_at': 'Sun Nov 08 00:33:53 +0000 2020', 'id_str': '1325235055950704644', 'text': 'RT @colunapatriota: URGENTE: As eleições americanas serão definidas pela SUPREMA CORTE AMERICANA, Joe Biden foi orientado a se declarar Pre…', '_id': ObjectId('5fa73cf6a3f848eb84ea3cfe')}
# {'created_at': 'Sun Nov 08 00:33:54 +0000 2020', 'id_str': '1325235061319487494', 'text': 'RT @CNNBrasil: Acompanhe a cobertura completa da reta final das eleições americanas https://t.co/XwemPzWezj', '_id': ObjectId('5fa73cf8a3f848eb84ea3cff')}
# {'created_at': 'Sun Nov 08 00:34:00 +0000 2020', 'id_str': '1325235086539808768', 'text': 'RT @GugaNoblat: Se nenhum filho do Bolsonaro falou merda sobre as eleições americanas hoje, é sinal que foram orientados a se calar. Que bo…', '_id': ObjectId('5fa73cfea3f848eb84ea3d00')}
# {'created_at': 'Sun Nov 08 00:34:01 +0000 2020', 'id_str': '1325235086959276032', 'text': 'Dando RT pra ver se o tonho da lua pistola', '_id': ObjectId('5fa73cfea3f848eb84ea3d01')}
# {'created_at': 'Sun Nov 08 00:34:03 +0000 2020', 'id_str': '1325235095335219201', 'text': 'RT @colunapatriota: URGENTE: As eleições americanas serão definidas pela SUPREMA CORTE AMERICANA, Joe Biden foi orientado a se declarar Pre…', '_id': ObjectId('5fa73d00a3f848eb84ea3d02')}
# {'created_at': 'Sun Nov 08 00:34:06 +0000 2020', 'id_str': '1325235107796574211', 'text': 'RT @GwgMinas: FicaADica - Esse é o Twitter:\nA mídia americana e mundial esta declarando o resultado das eleições americanas.\nOs órgãos ofic…', '_id': ObjectId('5fa73d03a3f848eb84ea3d03')}
# {'created_at': 'Sun Nov 08 00:34:22 +0000 2020', 'id_str': '1325235175333257216', 'text': 'RT @AlbuquerqueDavy: A imprensa mundial, inclusive no Brasil, segue ignorando as inúmeras denúncias de fraude nas eleições americanas. Não…', '_id': ObjectId('5fa73d13a3f848eb84ea3d04')}
# {'created_at': 'Sun Nov 08 00:34:28 +0000 2020', 'id_str': '1325235202654920708', 'text': 'RT @Madruga004: Caraca olha a torcida da Globo Lixo, para noticiar algo sobre eleições americanas.\n\n"A Gente Virou".\n\nCalma, ainda vai ter…', '_id': ObjectId('5fa73d19a3f848eb84ea3d05')}
# {'created_at': 'Sun Nov 08 00:34:30 +0000 2020', 'id_str': '1325235209512562688', 'text': 'RT @WiLLBarbudo: Os msm q estão apoiando o roubo nas eleições Americanas, ficaram quietos e apoiando Lula e Dilma enquanto roubavam o BR. T…', '_id': ObjectId('5fa73d1ba3f848eb84ea3d06')}
# {'created_at': 'Sun Nov 08 00:34:34 +0000 2020', 'id_str': '1325235227623501825', 'text': '@hilde_angel Só trabalha nas eleições americanas e quando tem perrengue no Oriente médio.', '_id': ObjectId('5fa73d1fa3f848eb84ea3d07')}
# {'created_at': 'Sun Nov 08 00:34:34 +0000 2020', 'id_str': '1325235228902887425', 'text': 'RT @Biakicis: Vamos aguardar a justiça decidir se houve ou não fraude nas eleições americanas e quem é o vencedor. Até lá, toda manifestaçã…', '_id': ObjectId('5fa73d20a3f848eb84ea3d08')}
# {'created_at': 'Sun Nov 08 00:34:35 +0000 2020', 'id_str': '1325235229355888640', 'text': 'RT @WiLLBarbudo: Os msm q estão apoiando o roubo nas eleições Americanas, ficaram quietos e apoiando Lula e Dilma enquanto roubavam o BR. T…', '_id': ObjectId('5fa73d20a3f848eb84ea3d09')}
# {'created_at': 'Sun Nov 08 00:34:38 +0000 2020', 'id_str': '1325235244560166913', 'text': 'RT @bernardokuster2: Além de todas as evidências de fraudes nas eleições americanas, uma coisa tem de ser definida: os institutos de pesqui…', '_id': ObjectId('5fa73d23a3f848eb84ea3d0a')}
# {'created_at': 'Sun Nov 08 00:34:42 +0000 2020', 'id_str': '1325235260897038338', 'text': 'RT @colunapatriota: URGENTE: As eleições americanas serão definidas pela SUPREMA CORTE AMERICANA, Joe Biden foi orientado a se declarar Pre…', '_id': ObjectId('5fa73d27a3f848eb84ea3d0b')}
# {'created_at': 'Sun Nov 08 00:34:42 +0000 2020', 'id_str': '1325235262012665856', 'text': 'RT @Biakicis: Vamos aguardar a justiça decidir se houve ou não fraude nas eleições americanas e quem é o vencedor. Até lá, toda manifestaçã…', '_id': ObjectId('5fa73d27a3f848eb84ea3d0c')}
# {'created_at': 'Sun Nov 08 00:34:42 +0000 2020', 'id_str': '1325235262516027397', 'text': '@jairbolsonaro @secomvc @Minas_Energia @ANEEL_govbr @DefesaGovBr Presida, fala aí das eleições americanas. Como fica o Brasil sem Trump?', '_id': ObjectId('5fa73d28a3f848eb84ea3d0d')}
# {'created_at': 'Sun Nov 08 00:34:43 +0000 2020', 'id_str': '1325235265007472642', 'text': '@RomeuZema\nGovernador, parabenizando o Joe Biden, por suposta vitória das eleições Americanas? O resultado saiu por… https://t.co/5t2lApttpB', '_id': ObjectId('5fa73d28a3f848eb84ea3d0e')}
# {'created_at': 'Sun Nov 08 00:34:44 +0000 2020', 'id_str': '1325235267796684800', 'text': 'RT @GugaNoblat: Se nenhum filho do Bolsonaro falou merda sobre as eleições americanas hoje, é sinal que foram orientados a se calar. Que bo…', '_id': ObjectId('5fa73d29a3f848eb84ea3d0f')}
# {'created_at': 'Sun Nov 08 00:34:45 +0000 2020', 'id_str': '1325235272301342721', 'text': 'ainda falando das eleições americanas, to pensando aqui que é quase certeza que a Gaga não vem pro BRA até 2022 né?… https://t.co/T1NwsqAn0Y', '_id': ObjectId('5fa73d2aa3f848eb84ea3d10')}
# {'created_at': 'Sun Nov 08 00:34:46 +0000 2020', 'id_str': '1325235276453720068', 'text': 'RT @matandomatheus: a FANCAM da urna eletrônica está passando na sua timeline 💅  https://t.co/yNCutiGUqk', '_id': ObjectId('5fa73d2ba3f848eb84ea3d11')}
# {'created_at': 'Sun Nov 08 00:34:47 +0000 2020', 'id_str': '1325235282912927746', 'text': 'ENTENDA AS DENÚNCIAS DE FRAUDE NA ELEIÇÕES AMERICANAS https://t.co/mLmiBZzWCH via @YouTube', '_id': ObjectId('5fa73d2ca3f848eb84ea3d12')}
# {'created_at': 'Sun Nov 08 00:34:47 +0000 2020', 'id_str': '1325235283437252608', 'text': 'E a mídia perdendo tempo com eleições americanas', '_id': ObjectId('5fa73d2da3f848eb84ea3d13')}
# {'created_at': 'Sun Nov 08 00:34:48 +0000 2020', 'id_str': '1325235285148504068', 'text': 'RT @carnielli_lucio: Arnaldo, eu vou concordar com o baixinho. \nEleição com mais de um candidato só dá dor de cabeça. https://t.co/OlsDYt4y…', '_id': ObjectId('5fa73d2da3f848eb84ea3d14')}
# {'created_at': 'Sun Nov 08 00:34:51 +0000 2020', 'id_str': '1325235300549922818', 'text': 'RT @goncalo_uva: Gostava que os portugueses se importassem tanto com as nossas eleições como se preocupam como as americanas. Era meio cami…', '_id': ObjectId('5fa73d31a3f848eb84ea3d15')}
# {'created_at': 'Sun Nov 08 00:34:53 +0000 2020', 'id_str': '1325235307470532609', 'text': 'RT @ToniettoChris: Sei que as eleições presidenciais norte-americanas não estão definidas, graças a Deus! Contudo, não deixa de ser um dia…', '_id': ObjectId('5fa73d32a3f848eb84ea3d16')}
# {'created_at': 'Sun Nov 08 00:34:53 +0000 2020', 'id_str': '1325235308003201027', 'text': 'RT @Biakicis: Vamos aguardar a justiça decidir se houve ou não fraude nas eleições americanas e quem é o vencedor. Até lá, toda manifestaçã…', '_id': ObjectId('5fa73d32a3f848eb84ea3d17')}
# {'created_at': 'Sun Nov 08 00:34:55 +0000 2020', 'id_str': '1325235317260083200', 'text': 'RT @DiogoAfonso24: Pessoal, quick reminder que a política não é importante exclusivamente quando é mediática. As nossas eleições têm mais i…', '_id': ObjectId('5fa73d35a3f848eb84ea3d18')}
# {'created_at': 'Sun Nov 08 00:34:58 +0000 2020', 'id_str': '1325235327305478144', 'text': 'RT @LeitoraCompuls2: Agora que já despachámos as eleições americanas vamos a assuntos de interesse nacional. Hoje há futebol?', '_id': ObjectId('5fa73d37a3f848eb84ea3d19')}
# {'created_at': 'Sun Nov 08 00:35:00 +0000 2020', 'id_str': '1325235334783922177', 'text': 'RT @GugaNoblat: Se nenhum filho do Bolsonaro falou merda sobre as eleições americanas hoje, é sinal que foram orientados a se calar. Que bo…', '_id': ObjectId('5fa73d39a3f848eb84ea3d1a')}
# {'created_at': 'Sun Nov 08 00:35:02 +0000 2020', 'id_str': '1325235344145608705', 'text': 'RT @Biakicis: Vamos aguardar a justiça decidir se houve ou não fraude nas eleições americanas e quem é o vencedor. Até lá, toda manifestaçã…', '_id': ObjectId('5fa73d3ba3f848eb84ea3d1b')}
# {'created_at': 'Sun Nov 08 00:35:03 +0000 2020', 'id_str': '1325235347853352961', 'text': 'RT @conservadoratha: Eu tinha uma vida tranquila até conhecer o Bolsonaro. Agora, até as eleições americanas me deixam apreensiva.🤣🤣🤣🤣', '_id': ObjectId('5fa73d3ca3f848eb84ea3d1c')}
# {'created_at': 'Sun Nov 08 00:35:05 +0000 2020', 'id_str': '1325235357722562561', 'text': 'Eu não entendo. Como deixaram empresa de tecnologia ligado ao ditador Maduro fazer a votação nos EUA ??\n\nÉ querer a… https://t.co/g5QgNP3omy', '_id': ObjectId('5fa73d3ea3f848eb84ea3d1d')}
# {'created_at': 'Sun Nov 08 00:35:07 +0000 2020', 'id_str': '1325235364248883201', 'text': 'RT @Biakicis: Vamos aguardar a justiça decidir se houve ou não fraude nas eleições americanas e quem é o vencedor. Até lá, toda manifestaçã…', '_id': ObjectId('5fa73d40a3f848eb84ea3d1e')}
# {'created_at': 'Sun Nov 08 00:35:11 +0000 2020', 'id_str': '1325235383618187266', 'text': 'RT @GugaNoblat: Se nenhum filho do Bolsonaro falou merda sobre as eleições americanas hoje, é sinal que foram orientados a se calar. Que bo…', '_id': ObjectId('5fa73d44a3f848eb84ea3d1f')}
# {'created_at': 'Sun Nov 08 00:35:15 +0000 2020', 'id_str': '1325235400387006464', 'text': 'RT @colunapatriota: URGENTE: As eleições americanas serão definidas pela SUPREMA CORTE AMERICANA, Joe Biden foi orientado a se declarar Pre…', '_id': ObjectId('5fa73d48a3f848eb84ea3d20')}
# {'created_at': 'Sun Nov 08 00:35:16 +0000 2020', 'id_str': '1325235401599184896', 'text': 'as eleições americanas me deixaram tão em êxtase que eu tô no pique de reassistir house of cards', '_id': ObjectId('5fa73d49a3f848eb84ea3d21')}
# {'created_at': 'Sun Nov 08 00:35:16 +0000 2020', 'id_str': '1325235402828034049', 'text': 'RT @carnielli_lucio: Arnaldo, eu vou concordar com o baixinho. \nEleição com mais de um candidato só dá dor de cabeça. https://t.co/OlsDYt4y…', '_id': ObjectId('5fa73d49a3f848eb84ea3d22')}
# {'created_at': 'Sun Nov 08 00:35:17 +0000 2020', 'id_str': '1325235405852119040', 'text': 'RT @Theur_exe: Pro governo Bolsonaro o melhor a se fazer é ter paciência e se manter em silêncio até o fim das eleições. \n Não parabenizar…', '_id': ObjectId('5fa73d4aa3f848eb84ea3d23')}
# {'created_at': 'Sun Nov 08 00:35:21 +0000 2020', 'id_str': '1325235424697192448', 'text': '@Cleiton84616793 Foi tudo montagem e dublagem? Nada disso q está passando no Jornal aconteceu? A Globo provocou até… https://t.co/E8tMmPh8MA', '_id': ObjectId('5fa73d4ea3f848eb84ea3d24')}
# {'created_at': 'Sun Nov 08 00:35:26 +0000 2020', 'id_str': '1325235444406251521', 'text': '#BoicoteaoOutback', '_id': ObjectId('5fa73d53a3f848eb84ea3d25')}
# {'created_at': 'Sun Nov 08 00:35:28 +0000 2020', 'id_str': '1325235454506131456', 'text': 'RT @CNNBrasil: Acompanhe a cobertura completa da reta final das eleições americanas https://t.co/XwemPzWezj', '_id': ObjectId('5fa73d55a3f848eb84ea3d26')}
# {'created_at': 'Sun Nov 08 00:35:34 +0000 2020', 'id_str': '1325235480519118849', 'text': 'Vc quer assistir um jornal na TV é muito difícil;só fala nas eleições americanas.', '_id': ObjectId('5fa73d5ca3f848eb84ea3d27')}
# {'created_at': 'Sun Nov 08 00:35:35 +0000 2020', 'id_str': '1325235483346145285', 'text': 'RT @GugaNoblat: Se nenhum filho do Bolsonaro falou merda sobre as eleições americanas hoje, é sinal que foram orientados a se calar. Que bo…', '_id': ObjectId('5fa73d5ca3f848eb84ea3d28')}
# {'created_at': 'Sun Nov 08 00:35:38 +0000 2020', 'id_str': '1325235494666592258', 'text': 'Alerta ! Fake news detectada. Em nenhum momento @EduardoBraide se manifestou sobre as eleições americanas. A pagina… https://t.co/Dsp40caEea', '_id': ObjectId('5fa73d5fa3f848eb84ea3d29')}
# {'created_at': 'Sun Nov 08 00:35:42 +0000 2020', 'id_str': '1325235511569625088', 'text': 'RT @GugaNoblat: Se nenhum filho do Bolsonaro falou merda sobre as eleições americanas hoje, é sinal que foram orientados a se calar. Que bo…', '_id': ObjectId('5fa73d63a3f848eb84ea3d2a')}
# {'created_at': 'Sun Nov 08 00:35:42 +0000 2020', 'id_str': '1325235513641611266', 'text': '#GoTrump2020\n\nCount every LEGAL vote. \nBrazilian people are aware of the fraud. This is a shame for the democratic… https://t.co/r4bSqNbmOK', '_id': ObjectId('5fa73d64a3f848eb84ea3d2b')}
# {'created_at': 'Sun Nov 08 00:35:43 +0000 2020', 'id_str': '1325235514560090113', 'text': 'RT @Biakicis: Vamos aguardar a justiça decidir se houve ou não fraude nas eleições americanas e quem é o vencedor. Até lá, toda manifestaçã…', '_id': ObjectId('5fa73d64a3f848eb84ea3d2c')}
# {'created_at': 'Sun Nov 08 00:35:45 +0000 2020', 'id_str': '1325235525108772867', 'text': '#BoicoteaoOutback', '_id': ObjectId('5fa73d66a3f848eb84ea3d2d')}
# {'created_at': 'Sun Nov 08 00:35:59 +0000 2020', 'id_str': '1325235582239469573', 'text': 'RT @oswaldojor: A Fox News acaba de anunciar a vitória de Biden nas eleições americanas. A fraude nas urnas foi abafada pelo mecanismo. Ont…', '_id': ObjectId('5fa73d74a3f848eb84ea3d2e')}
# {'created_at': 'Sun Nov 08 00:36:02 +0000 2020', 'id_str': '1325235596231651329', 'text': 'RT @fabifbbr: Eleições Americanas- Pensilvania. A secretária de Estado, Kathy Boockvar,  que é uma democrata, havia ordenado que todas as c…', '_id': ObjectId('5fa73d77a3f848eb84ea3d2f')}
# {'created_at': 'Sun Nov 08 00:36:08 +0000 2020', 'id_str': '1325235620546011136', 'text': 'RT @colunapatriota: URGENTE: As eleições americanas serão definidas pela SUPREMA CORTE AMERICANA, Joe Biden foi orientado a se declarar Pre…', '_id': ObjectId('5fa73d7da3f848eb84ea3d30')}
# {'created_at': 'Sun Nov 08 00:36:08 +0000 2020', 'id_str': '1325235621250682882', 'text': 'RT @colunapatriota: URGENTE: As eleições americanas serão definidas pela SUPREMA CORTE AMERICANA, Joe Biden foi orientado a se declarar Pre…', '_id': ObjectId('5fa73d7da3f848eb84ea3d31')}
# {'created_at': 'Sun Nov 08 00:36:10 +0000 2020', 'id_str': '1325235629475631104', 'text': 'RT @iaradsobral: Vi muitos jovens a acompanhar as eleições americanas de perto e a sentir o medo de uma reeleição. Espero que transfiram es…', '_id': ObjectId('5fa73d7fa3f848eb84ea3d32')}
# {'created_at': 'Sun Nov 08 00:36:10 +0000 2020', 'id_str': '1325235629643485186', 'text': 'RT @alebarbieriadv: Estamos a 8 dias das eleições municipais, mas o único assunto que engaja o público são as eleições nos EUA. Se o brasil…', '_id': ObjectId('5fa73d7fa3f848eb84ea3d33')}
# {'created_at': 'Sun Nov 08 00:36:10 +0000 2020', 'id_str': '1325235631241486341', 'text': 'RT @oswaldojor: A Fox News acaba de anunciar a vitória de Biden nas eleições americanas. A fraude nas urnas foi abafada pelo mecanismo. Ont…', '_id': ObjectId('5fa73d7fa3f848eb84ea3d34')}
# {'created_at': 'Sun Nov 08 00:36:16 +0000 2020', 'id_str': '1325235654524080128', 'text': 'RT @colunapatriota: URGENTE: As eleições americanas serão definidas pela SUPREMA CORTE AMERICANA, Joe Biden foi orientado a se declarar Pre…', '_id': ObjectId('5fa73d85a3f848eb84ea3d35')}
# {'created_at': 'Sun Nov 08 00:36:17 +0000 2020', 'id_str': '1325235660542840840', 'text': 'RT @BR_DeTodos200Mi: Eu não entendo. Como deixaram empresa de tecnologia ligado ao ditador Maduro fazer a votação nos EUA ??\n\nÉ querer assi…', '_id': ObjectId('5fa73d86a3f848eb84ea3d36')}
# {'created_at': 'Sun Nov 08 00:36:20 +0000 2020', 'id_str': '1325235671452282880', 'text': 'RT @alebarbieriadv: Estamos a 8 dias das eleições municipais, mas o único assunto que engaja o público são as eleições nos EUA. Se o brasil…', '_id': ObjectId('5fa73d89a3f848eb84ea3d37')}
# {'created_at': 'Sun Nov 08 00:36:26 +0000 2020', 'id_str': '1325235697633157120', 'text': '@paulomathias Será que nas eleições  americanas  tem fundão eleitoral??🤔', '_id': ObjectId('5fa73d8fa3f848eb84ea3d38')}
# {'created_at': 'Sun Nov 08 00:36:27 +0000 2020', 'id_str': '1325235700678205440', 'text': 'RT @iaradsobral: Vi muitos jovens a acompanhar as eleições americanas de perto e a sentir o medo de uma reeleição. Espero que transfiram es…', '_id': ObjectId('5fa73d90a3f848eb84ea3d39')}
# {'created_at': 'Sun Nov 08 00:36:30 +0000 2020', 'id_str': '1325235715685437440', 'text': 'RT @Biakicis: Vamos aguardar a justiça decidir se houve ou não fraude nas eleições americanas e quem é o vencedor. Até lá, toda manifestaçã…', '_id': ObjectId('5fa73d94a3f848eb84ea3d3a')}
# {'created_at': 'Sun Nov 08 00:36:40 +0000 2020', 'id_str': '1325235755036397568', 'text': 'RT @GugaNoblat: Se nenhum filho do Bolsonaro falou merda sobre as eleições americanas hoje, é sinal que foram orientados a se calar. Que bo…', '_id': ObjectId('5fa73d9da3f848eb84ea3d3b')}
# {'created_at': 'Sun Nov 08 00:36:40 +0000 2020', 'id_str': '1325235756223373312', 'text': 'Muito espantado como as eleições Americanas influenciam em tudo aqui no Br', '_id': ObjectId('5fa73d9da3f848eb84ea3d3c')}
# {'created_at': 'Sun Nov 08 00:36:48 +0000 2020', 'id_str': '1325235788855078913', 'text': 'RT @MarleneFFL: PESSOAL eu tô com TRUMP!  Vamos tomar como exemplo o q tá acontecendo agr nas eleições americanas, pque nós vamos enfrentar…', '_id': ObjectId('5fa73da5a3f848eb84ea3d3d')}
# {'created_at': 'Sun Nov 08 00:36:50 +0000 2020', 'id_str': '1325235796505456641', 'text': 'RT @alebarbieriadv: Eu pensei que estivesse claro, mas parece que faltou o desenho no tweet anterior: eu não disse que o brasileiro não tem…', '_id': ObjectId('5fa73da7a3f848eb84ea3d3e')}
# {'created_at': 'Sun Nov 08 00:36:50 +0000 2020', 'id_str': '1325235797403066374', 'text': 'RT @scarlosferrari: Não houve FRAUDE nas eleições americanas. Então o que houve? Olha, nada de mais, apenas 21 mil mortos votaram em Biden,…', '_id': ObjectId('5fa73da7a3f848eb84ea3d3f')}
# {'created_at': 'Sun Nov 08 00:36:51 +0000 2020', 'id_str': '1325235803178594304', 'text': 'RT @JornalBSM: Mídia “elege” Biden; Trump vai à Justiça\n\nMesmo com denúncias de fraudes, imprensa anuncia o democrata Joe Biden como venced…', '_id': ObjectId('5fa73da8a3f848eb84ea3d40')}
# {'created_at': 'Sun Nov 08 00:36:53 +0000 2020', 'id_str': '1325235809549754369', 'text': 'RT @bernardokuster2: A mídia hoje correu anunciar a vitória decisiva de Joe Biden nas eleições americanas. Imagine, só imagine!, se depois…', '_id': ObjectId('5fa73daaa3f848eb84ea3d41')}
# {'created_at': 'Sun Nov 08 00:36:58 +0000 2020', 'id_str': '1325235832345784320', 'text': 'RT @disturst: És fã das eleições americanas? Diz 3 álbuns', '_id': ObjectId('5fa73dafa3f848eb84ea3d42')}
# {'created_at': 'Sun Nov 08 00:36:59 +0000 2020', 'id_str': '1325235833746698243', 'text': '"Trump diz que vai entrar na Justiça para contestar resultado das eleições americanas"  https://t.co/tZYCKA1jLM', '_id': ObjectId('5fa73db0a3f848eb84ea3d43')}
# {'created_at': 'Sun Nov 08 00:37:09 +0000 2020', 'id_str': '1325235877103153152', 'text': 'RT @scarlosferrari: Não houve FRAUDE nas eleições americanas. Então o que houve? Olha, nada de mais, apenas 21 mil mortos votaram em Biden,…', '_id': ObjectId('5fa73dbaa3f848eb84ea3d44')}
# ...
# {'created_at': 'Sun Nov 08 01:32:40 +0000 2020', 'id_str': '1325249848057212928', 'text': 'RUMOR: le0jahjah fraudou as eleições americanas !', '_id': ObjectId('5fa74abda3f848eb84ea4262')}
# {'created_at': 'Sun Nov 08 01:32:46 +0000 2020', 'id_str': '1325249872103170050', 'text': 'É meus caros, as eleições americanas estão longe do fim. Diferente da Grande Midia que já deu a vitória a Biden, RE… https://t.co/LFigAoIpa3', '_id': ObjectId('5fa74ac3a3f848eb84ea4263')}
# {'created_at': 'Sun Nov 08 01:32:48 +0000 2020', 'id_str': '1325249880042991616', 'text': 'RT @conservadoratha: Eu tinha uma vida tranquila até conhecer o Bolsonaro. Agora, até as eleições americanas me deixam apreensiva.🤣🤣🤣🤣', '_id': ObjectId('5fa74ac5a3f848eb84ea4264')}
# {'created_at': 'Sun Nov 08 01:32:49 +0000 2020', 'id_str': '1325249887064248320', 'text': 'Vamos rodar o assunto, chega das eleições americanas', '_id': ObjectId('5fa74ac6a3f848eb84ea4265')}
# {'created_at': 'Sun Nov 08 01:32:50 +0000 2020', 'id_str': '1325249888595173376', 'text': 'RT @CNNBrasil: Acompanhe a cobertura completa da reta final das eleições americanas https://t.co/XwemPzWezj', '_id': ObjectId('5fa74ac7a3f848eb84ea4266')}
# {'created_at': 'Sun Nov 08 01:32:50 +0000 2020', 'id_str': '1325249892114182151', 'text': 'RT @CNNBrasil: Acompanhe a cobertura completa da reta final das eleições americanas https://t.co/XwemPzWezj', '_id': ObjectId('5fa74ac8a3f848eb84ea4267')}
# {'created_at': 'Sun Nov 08 01:32:54 +0000 2020', 'id_str': '1325249905888256000', 'text': 'RT @CNNBrasil: Acompanhe a cobertura completa da reta final das eleições americanas https://t.co/XwemPzWezj', '_id': ObjectId('5fa74acba3f848eb84ea4268')}
# {'created_at': 'Sun Nov 08 01:32:56 +0000 2020', 'id_str': '1325249915828789249', 'text': 'RT @CNNBrasil: Acompanhe a cobertura completa da reta final das eleições americanas https://t.co/XwemPzWezj', '_id': ObjectId('5fa74acda3f848eb84ea4269')}
# {'created_at': 'Sun Nov 08 01:32:59 +0000 2020', 'id_str': '1325249929783160834', 'text': 'RT @caldeira_odair: @jairbolsonaro @govbr Pelo amor de Deus presidente 🙏 não vai ceder a pressão dessa mídia mentirosa e aceitar o resultad…', '_id': ObjectId('5fa74ad1a3f848eb84ea426a')}
# {'created_at': 'Sun Nov 08 01:33:00 +0000 2020', 'id_str': '1325249931330908161', 'text': 'RT @conservadoratha: Eu tinha uma vida tranquila até conhecer o Bolsonaro. Agora, até as eleições americanas me deixam apreensiva.🤣🤣🤣🤣', '_id': ObjectId('5fa74ad1a3f848eb84ea426b')}
# {'created_at': 'Sun Nov 08 01:33:02 +0000 2020', 'id_str': '1325249939845345284', 'text': 'RT @luide: até agora nenhuma teoria conserva envolveu o lula e o pt na fraude das eleições americanas\n\nturma tá pouco criativa', '_id': ObjectId('5fa74ad3a3f848eb84ea426c')}
# {'created_at': 'Sun Nov 08 01:33:05 +0000 2020', 'id_str': '1325249953514524672', 'text': 'RT @CNNBrasil: Acompanhe a cobertura completa da reta final das eleições americanas https://t.co/XwemPzWezj', '_id': ObjectId('5fa74ad6a3f848eb84ea426d')}
# {'created_at': 'Sun Nov 08 01:33:06 +0000 2020', 'id_str': '1325249959499870212', 'text': 'RT @guidalovatoo: se vocês se interessassem tanto pelas eleições portuguesas como se interessam pelas americanas :)', '_id': ObjectId('5fa74ad8a3f848eb84ea426e')}
# {'created_at': 'Sun Nov 08 01:33:07 +0000 2020', 'id_str': '1325249962666577920', 'text': 'RT @CNNBrasil: Acompanhe a cobertura completa da reta final das eleições americanas https://t.co/XwemPzWezj', '_id': ObjectId('5fa74ad8a3f848eb84ea426f')}
# {'created_at': 'Sun Nov 08 01:33:07 +0000 2020', 'id_str': '1325249963673198593', 'text': 'RT @iaradsobral: Vi muitos jovens a acompanhar as eleições americanas de perto e a sentir o medo de uma reeleição. Espero que transfiram es…', '_id': ObjectId('5fa74ad9a3f848eb84ea4270')}
# {'created_at': 'Sun Nov 08 01:33:08 +0000 2020', 'id_str': '1325249964159741957', 'text': 'A vice-presidente eleita dos Estados Unidos, Kamala Harris, faz o primeiro discurso oficial após a vitória nas eleições americanas.', '_id': ObjectId('5fa74ad9a3f848eb84ea4271')}
# {'created_at': 'Sun Nov 08 01:33:08 +0000 2020', 'id_str': '1325249964608532481', 'text': 'RT @CNNBrasil: Acompanhe a cobertura completa da reta final das eleições americanas https://t.co/XwemPzWezj', '_id': ObjectId('5fa74ad9a3f848eb84ea4272')}
# {'created_at': 'Sun Nov 08 01:33:11 +0000 2020', 'id_str': '1325249977845755904', 'text': 'RT @OliveiraMyrtes: Enquanto Isso, as Eleições Americanas continuam embora manchadas pela nojenta esquerda infelizmente...🤮\n#FraudeNasEleiç…', '_id': ObjectId('5fa74adca3f848eb84ea4273')}
# {'created_at': 'Sun Nov 08 01:33:12 +0000 2020', 'id_str': '1325249983092809735', 'text': 'RT @alebarbieriadv: Estamos a 8 dias das eleições municipais, mas o único assunto que engaja o público são as eleições nos EUA. Se o brasil…', '_id': ObjectId('5fa74adda3f848eb84ea4274')}
# {'created_at': 'Sun Nov 08 01:33:17 +0000 2020', 'id_str': '1325250003376381953', 'text': 'RT @POPline: É festa nos Estados Unidos! A vitória de Joe Biden nas eleições norte-americanas levou o hit de @MileyCyrus de volta ao ITunes…', '_id': ObjectId('5fa74ae2a3f848eb84ea4275')}
# {'created_at': 'Sun Nov 08 01:33:19 +0000 2020', 'id_str': '1325250012910145536', 'text': 'RT @luide: até agora nenhuma teoria conserva envolveu o lula e o pt na fraude das eleições americanas\n\nturma tá pouco criativa', '_id': ObjectId('5fa74ae4a3f848eb84ea4276')}
# {'created_at': 'Sun Nov 08 01:33:19 +0000 2020', 'id_str': '1325250012876591104', 'text': 'Trump governará até 2024!', '_id': ObjectId('5fa74ae4a3f848eb84ea4277')}
# {'created_at': 'Sun Nov 08 01:33:22 +0000 2020', 'id_str': '1325250023655923712', 'text': 'RT @POPline: É festa nos Estados Unidos! A vitória de Joe Biden nas eleições norte-americanas levou o hit de @MileyCyrus de volta ao ITunes…', '_id': ObjectId('5fa74ae7a3f848eb84ea4278')}
# {'created_at': 'Sun Nov 08 01:33:23 +0000 2020', 'id_str': '1325250029351735296', 'text': 'RT @scarlosferrari: Não houve FRAUDE nas eleições americanas. Então o que houve? Olha, nada de mais, apenas 21 mil mortos votaram em Biden,…', '_id': ObjectId('5fa74ae8a3f848eb84ea4279')}
# {'created_at': 'Sun Nov 08 01:33:24 +0000 2020', 'id_str': '1325250032245862401', 'text': 'RT @guidalovatoo: se vocês se interessassem tanto pelas eleições portuguesas como se interessam pelas americanas :)', '_id': ObjectId('5fa74ae9a3f848eb84ea427a')}
# {'created_at': 'Sun Nov 08 01:33:27 +0000 2020', 'id_str': '1325250044891701249', 'text': 'RT @Biakicis: Vamos aguardar a justiça decidir se houve ou não fraude nas eleições americanas e quem é o vencedor. Até lá, toda manifestaçã…', '_id': ObjectId('5fa74aeca3f848eb84ea427b')}
# {'created_at': 'Sun Nov 08 01:33:31 +0000 2020', 'id_str': '1325250062021226497', 'text': 'RT @oswaldojor: A Fox News acaba de anunciar a vitória de Biden nas eleições americanas. A fraude nas urnas foi abafada pelo mecanismo. Ont…', '_id': ObjectId('5fa74af0a3f848eb84ea427c')}
# {'created_at': 'Sun Nov 08 01:33:31 +0000 2020', 'id_str': '1325250063761862657', 'text': 'RT @Hederso11000770: Mais supostas provas de fraude contra o Trump nas eleições americanas de 2020 vão surgindo a todo minuto na internet.…', '_id': ObjectId('5fa74af0a3f848eb84ea427d')}
# {'created_at': 'Sun Nov 08 01:33:33 +0000 2020', 'id_str': '1325250070321782785', 'text': '@marcionobrega Eleições americanas?', '_id': ObjectId('5fa74af2a3f848eb84ea427e')}
# {'created_at': 'Sun Nov 08 01:33:36 +0000 2020', 'id_str': '1325250081499525121', 'text': 'RT @colunapatriota: URGENTE: As eleições americanas serão definidas pela SUPREMA CORTE AMERICANA, Joe Biden foi orientado a se declarar Pre…', '_id': ObjectId('5fa74af5a3f848eb84ea427f')}
# {'created_at': 'Sun Nov 08 01:33:36 +0000 2020', 'id_str': '1325250084376891397', 'text': 'RT @bernardokuster2: Além de todas as evidências de fraudes nas eleições americanas, uma coisa tem de ser definida: os institutos de pesqui…', '_id': ObjectId('5fa74af5a3f848eb84ea4280')}
# {'created_at': 'Sun Nov 08 01:33:39 +0000 2020', 'id_str': '1325250097467240449', 'text': 'RT @Madruga004: Caraca olha a torcida da Globo Lixo, para noticiar algo sobre eleições americanas.\n\n"A Gente Virou".\n\nCalma, ainda vai ter…', '_id': ObjectId('5fa74af9a3f848eb84ea4281')}
# {'created_at': 'Sun Nov 08 01:33:42 +0000 2020', 'id_str': '1325250107776917504', 'text': 'admiração só aumenta', '_id': ObjectId('5fa74afba3f848eb84ea4282')}
# {'created_at': 'Sun Nov 08 01:33:44 +0000 2020', 'id_str': '1325250115318280193', 'text': 'RT @scarlosferrari: Não houve FRAUDE nas eleições americanas. Então o que houve? Olha, nada de mais, apenas 21 mil mortos votaram em Biden,…', '_id': ObjectId('5fa74afda3f848eb84ea4283')}
# {'created_at': 'Sun Nov 08 01:33:45 +0000 2020', 'id_str': '1325250120041041922', 'text': 'RT @brsemcomunas: Trump governará até 2024!', '_id': ObjectId('5fa74affa3f848eb84ea4284')}
# {'created_at': 'Sun Nov 08 01:33:49 +0000 2020', 'id_str': '1325250138672082944', 'text': 'RT @AtalaiaBR: Depois de tudo o que vemos nessas eleições americanas, essa pauta deve ser prioridade máxima.\n\nPEC são dois turnos na Câmara…', '_id': ObjectId('5fa74b02a3f848eb84ea4285')}
# {'created_at': 'Sun Nov 08 01:33:51 +0000 2020', 'id_str': '1325250145043279872', 'text': 'RT @CNNBrasil: Acompanhe a cobertura completa da reta final das eleições americanas https://t.co/XwemPzWezj', '_id': ObjectId('5fa74b04a3f848eb84ea4286')}
# {'created_at': 'Sun Nov 08 01:33:51 +0000 2020', 'id_str': '1325250145668239362', 'text': 'RT @iaradsobral: Vi muitos jovens a acompanhar as eleições americanas de perto e a sentir o medo de uma reeleição. Espero que transfiram es…', '_id': ObjectId('5fa74b04a3f848eb84ea4287')}
# {'created_at': 'Sun Nov 08 01:33:51 +0000 2020', 'id_str': '1325250146419011587', 'text': 'Não houve FRAUDE nas eleições americanas.Então o que houve?Olha, nada de mais, apenas 21 mil mortos votaram em Bide… https://t.co/eamcROX3K2', '_id': ObjectId('5fa74b04a3f848eb84ea4288')}
# {'created_at': 'Sun Nov 08 01:33:52 +0000 2020', 'id_str': '1325250151192162305', 'text': 'RT @colunapatriota: URGENTE: As eleições americanas serão definidas pela SUPREMA CORTE AMERICANA, Joe Biden foi orientado a se declarar Pre…', '_id': ObjectId('5fa74b05a3f848eb84ea4289')}
# {'created_at': 'Sun Nov 08 01:33:54 +0000 2020', 'id_str': '1325250156992847872', 'text': 'RT @POPline: É festa nos Estados Unidos! A vitória de Joe Biden nas eleições norte-americanas levou o hit de @MileyCyrus de volta ao ITunes…', '_id': ObjectId('5fa74b07a3f848eb84ea428a')}
# {'created_at': 'Sun Nov 08 01:33:55 +0000 2020', 'id_str': '1325250164857171968', 'text': 'RT @colunapatriota: URGENTE: As eleições americanas serão definidas pela SUPREMA CORTE AMERICANA, Joe Biden foi orientado a se declarar Pre…', '_id': ObjectId('5fa74b09a3f848eb84ea428b')}
# {'created_at': 'Sun Nov 08 01:33:58 +0000 2020', 'id_str': '1325250173795184642', 'text': 'RT @Steh_Papaiano: Imprensa começou a pressão para tentar forçar uma declaração do Presidente @jairbolsonaro sobre as eleições americanas..…', '_id': ObjectId('5fa74b0ba3f848eb84ea428c')}
# {'created_at': 'Sun Nov 08 01:33:59 +0000 2020', 'id_str': '1325250181475037184', 'text': '@CarlaZambelli38 Urna eletrônica até um esquerdopata invade. Não precisa ser muito capaz. Quem tem dois tem um, quem tem um, não tem nenhum.', '_id': ObjectId('5fa74b0da3f848eb84ea428d')}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-56bfea83f13d> in <module>
#       1 # Iniciando o filtro e gravando os tweets no MongoDB
# ----> 2 stream.filter(track=keywords)
#
# ~/anaconda3/lib/python3.8/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~/anaconda3/lib/python3.8/site-packages/tweepy/streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~/anaconda3/lib/python3.8/site-packages/tweepy/streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~/anaconda3/lib/python3.8/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~/anaconda3/lib/python3.8/site-packages/tweepy/streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     517             else:
#     518                 cache_content = False
# --> 519                 data = self._fp.read(amt) if not fp_closed else b""
#     520                 if (
#     521                     amt != 0 and not data
#
# ~/anaconda3/lib/python3.8/http/client.py in read(self, amt)
#     452             # Amount is given, implement using readinto
#     453             b = bytearray(amt)
# --> 454             n = self.readinto(b)
#     455             return memoryview(b)[:n].tobytes()
#     456         else:
#
# ~/anaconda3/lib/python3.8/http/client.py in readinto(self, b)
#     486
#     487         if self.chunked:
# --> 488             return self._readinto_chunked(b)
#     489
#     490         if self.length is not None:
#
# ~/anaconda3/lib/python3.8/http/client.py in _readinto_chunked(self, b)
#     581         try:
#     582             while True:
# --> 583                 chunk_left = self._get_chunk_left()
#     584                 if chunk_left is None:
#     585                     return total_bytes
#
# ~/anaconda3/lib/python3.8/http/client.py in _get_chunk_left(self)
#     549                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     550             try:
# --> 551                 chunk_left = self._read_next_chunk_size()
#     552             except ValueError:
#     553                 raise IncompleteRead(b'')
#
# ~/anaconda3/lib/python3.8/http/client.py in _read_next_chunk_size(self)
#     509     def _read_next_chunk_size(self):
#     510         # Read the next chunk size from the file
# --> 511         line = self.fp.readline(_MAXLINE + 1)
#     512         if len(line) > _MAXLINE:
#     513             raise LineTooLong("chunk size")
#
# ~/anaconda3/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/anaconda3/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
stream.disconnect()
col.find_one()
# Out:
# {'_id': ObjectId('5fa5f6d9cae5a95ffe97ffe2'),
#  'created_at': 'Sat Nov 07 01:22:28 +0000 2020',
#  'id_str': '1324884894921732100',
#  'text': 'gente vcs realmente acham q os estadunidenses são burros por não usar urna eletrônica ou é meme?'}

# %% [markdown]
# ## Análise de Dados com Pandas e Scikit-Learn

# %%
# Importando pandas
import pandas as pd

# %%
#crio dicionario com os tweets
dataset = [{"created_at": item["created_at"], "text": item["text"],} for item in col.find()]

# %%
df = pd.DataFrame(dataset)

# %%
df
# Out:
#                           created_at  \
# 0     Sat Nov 07 01:22:28 +0000 2020
# 1     Sat Nov 07 01:22:32 +0000 2020
# 2     Sat Nov 07 01:22:33 +0000 2020
# 3     Sat Nov 07 01:22:36 +0000 2020
# 4     Sat Nov 07 01:22:44 +0000 2020
# ...                              ...
# 1857  Sun Nov 08 01:33:52 +0000 2020
# 1858  Sun Nov 08 01:33:54 +0000 2020
# 1859  Sun Nov 08 01:33:55 +0000 2020
# 1860  Sun Nov 08 01:33:58 +0000 2020
# 1861  Sun Nov 08 01:33:59 +0000 2020
#
#                                                    text
# 0     gente vcs realmente acham q os estadunidenses ...
# 1     RT @tuttyvasques: Um amigo corintiano matou a ...
# 2                                            Hahahahaha
# 3     RT @avelino_bego: STOP THE CUNT! https://t.co/...
# 4     RT @SF_Moro: Novo artigo na Crusoé sobre vacin...
# ...                                                 ...
# 1857  RT @colunapatriota: URGENTE: As eleições ameri...
# 1858  RT @POPline: É festa nos Estados Unidos! A vit...
# 1859  RT @colunapatriota: URGENTE: As eleições ameri...
# 1860  RT @Steh_Papaiano: Imprensa começou a pressão ...
# 1861  @CarlaZambelli38 Urna eletrônica até um esquer...
#
# [1862 rows x 2 columns]

# %%
# Importando o módulo Scikit Learn
from sklearn.feature_extraction.text import CountVectorizer

# %%
import sklearn

# %%
# criando matriz de documentos
cv = CountVectorizer()
count_matrix = cv.fit_transform(df.text)

# %%
#contando principais palavras
word_count = pd.DataFrame(cv.get_feature_names(), columns=["word"])
word_count["count"] = count_matrix.sum(axis=0).tolist()[0]
word_count = word_count.sort_values("count", ascending=False).reset_index(drop=True)
word_count[:50]
# Out:
#            word  count
# 0      eleições   1452
# 1    americanas   1412
# 2            rt   1371
# 3            de    845
# 4           que    810
# 5            as    643
# 6            se    583
# 7           nas    519
# 8           não    476
# 9         biden    385
# 10        https    373
# 11           co    358
# 12           do    319
# 13       fraude    318
# 14          das    294
# 15          até    273
# 16           da    231
# 17          uma    216
# 18        houve    216
# 19        vamos    195
# 20         para    192
# 21          foi    177
# 22          joe    177
# 23         quem    177
# 24           ou    165
# 25      justiça    163
# 26          com    160
# 27     vencedor    154
# 28           lá    153
# 29      vitória    151
# 30           os    149
# 31           em    148
# 32         toda    148
# 33    bolsonaro    146
# 34     biakicis    145
# 35     aguardar    143
# 36  manifestaçã    142
# 37      decidir    142
# 38        sobre    141
# 39           eu    138
# 40         pela    137
# 41        corte    134
# 42      suprema    132
# 43         mais    127
# 44        norte    124
# 45    definidas    120
# 46         hoje    117
# 47           um    113
# 48        mídia    111
# 49           no    110
